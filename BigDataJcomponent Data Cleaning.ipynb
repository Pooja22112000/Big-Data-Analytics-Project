# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
for dirname, _, filenames in os.walk('C:/Users/Pooja/OneDrive/Desktop'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:/Users/Pooja/OneDrive/Desktop\2.jpg
# C:/Users/Pooja/OneDrive/Desktop\Big Data Analytics Review 2.docx
# C:/Users/Pooja/OneDrive/Desktop\Big Data review2  code and output.docx
# C:/Users/Pooja/OneDrive/Desktop\bigdataanalytics review1.docx
# C:/Users/Pooja/OneDrive/Desktop\citycount.txt
# C:/Users/Pooja/OneDrive/Desktop\Day to Day Activities.docx
# C:/Users/Pooja/OneDrive/Desktop\desktop.ini
# C:/Users/Pooja/OneDrive/Desktop\Dev-C++.lnk
# C:/Users/Pooja/OneDrive/Desktop\Eclipse IDE for Java Developers - 2020-12.lnk
# C:/Users/Pooja/OneDrive/Desktop\enc_2.jpg
# C:/Users/Pooja/OneDrive/Desktop\fuel.csv
# C:/Users/Pooja/OneDrive/Desktop\fueldata.csv
# C:/Users/Pooja/OneDrive/Desktop\fueldatafile.csv
# C:/Users/Pooja/OneDrive/Desktop\grammar.docx
# C:/Users/Pooja/OneDrive/Desktop\katalon installation.docx
# C:/Users/Pooja/OneDrive/Desktop\logo.png
# C:/Users/Pooja/OneDrive/Desktop\LSm review 1 and 2.docx
# C:/Users/Pooja/OneDrive/Desktop\material expenses.xlsx
# ...

# %%
df=pd.read_csv("C:/Users/Pooja/OneDrive/Desktop/fuel.csv")
df
# Out:
#        Year   Manufacturer              Model  barrels08  barrelsA08  \
# 0      1995      Chevrolet    Pickup 2500 4WD  23.543571           0
# 1      1995      Chevrolet    Pickup 2500 4WD  23.886563           0
# 2      1995      Chevrolet     S10 Pickup 4WD  19.388824           0
# 3      1995         Nissan          Truck 4WD  21.974000           0
# 4      1995          Dodge  Dakota Pickup 4WD  25.354615           0
# ...     ...            ...                ...        ...         ...
# 44182  1992        Mercury             Tracer  12.677308           0
# 44183  1992  Mercedes-Benz     300D 2.5 Turbo  15.287400           0
# 44184  1992     Mitsubishi           Diamante  18.311667           0
# 44185  1992     Mitsubishi             Galant  15.695714           0
# 44186  1985           Ford    F250 Pickup 4WD  25.354615           0
#
#        charge120  charge240  city08  city08U  cityA08  ...  mfrCode  c240Dscr  \
# ...

# %%
print(df)
print("================================================")
print(df.info())
# Out:
#        Year   Manufacturer              Model  barrels08  barrelsA08  \
# 0      1995      Chevrolet    Pickup 2500 4WD  23.543571           0
# 1      1995      Chevrolet    Pickup 2500 4WD  23.886563           0
# 2      1995      Chevrolet     S10 Pickup 4WD  19.388824           0
# 3      1995         Nissan          Truck 4WD  21.974000           0
# 4      1995          Dodge  Dakota Pickup 4WD  25.354615           0
# ...     ...            ...                ...        ...         ...
# 44182  1992        Mercury             Tracer  12.677308           0
# 44183  1992  Mercedes-Benz     300D 2.5 Turbo  15.287400           0
# 44184  1992     Mitsubishi           Diamante  18.311667           0
# 44185  1992     Mitsubishi             Galant  15.695714           0
# 44186  1985           Ford    F250 Pickup 4WD  25.354615           0
#
#        charge120  charge240  city08  city08U  cityA08  ...  mfrCode  c240Dscr  \
# ...

# %%
df.describe()
# Out:
#                Year     barrels08    barrelsA08  charge120     charge240  \
# count  44187.000000  44187.000000  44187.000000    44187.0  44187.000000
# mean    2002.872519     17.085386      0.199833        0.0      0.071741
# std       11.822723      4.699161      1.036795        0.0      0.773559
# min     1984.000000      0.060000      0.000000        0.0      0.000000
# 25%     1992.000000     14.330870      0.000000        0.0      0.000000
# 50%     2004.000000     16.480500      0.000000        0.0      0.000000
# 75%     2013.000000     19.388824      0.000000        0.0      0.000000
# max     2022.000000     47.087143     18.000000        0.0     15.000000
#
#              city08       city08U       cityA08      cityA08U        cityCD  \
# count  44187.000000  44187.000000  44187.000000  44187.000000  44187.000000
# mean      18.755018      7.065472      0.814946      0.667097      0.000249
# std        9.031354     12.806830      6.281619      6.137284      0.033973
# ...

# %%
df.head()
# Out:
#    Year Manufacturer              Model  barrels08  barrelsA08  charge120  \
# 0  1995    Chevrolet    Pickup 2500 4WD  23.543571           0          0
# 1  1995    Chevrolet    Pickup 2500 4WD  23.886563           0          0
# 2  1995    Chevrolet     S10 Pickup 4WD  19.388824           0          0
# 3  1995       Nissan          Truck 4WD  21.974000           0          0
# 4  1995        Dodge  Dakota Pickup 4WD  25.354615           0          0
#
#    charge240  city08  city08U  cityA08  ...  mfrCode  c240Dscr  charge240b  \
# 0          0      13        0        0  ...      NaN       NaN           0
# 1          0      14        0        0  ...      NaN       NaN           0
# 2          0      15        0        0  ...      NaN       NaN           0
# 3          0      14        0        0  ...      NaN       NaN           0
# 4          0      11        0        0  ...      NaN       NaN           0
#
# ...

# %%
df.isnull()
# Out:
#         Year  Manufacturer  Model  barrels08  barrelsA08  charge120  \
# 0      False         False  False      False       False      False
# 1      False         False  False      False       False      False
# 2      False         False  False      False       False      False
# 3      False         False  False      False       False      False
# 4      False         False  False      False       False      False
# ...      ...           ...    ...        ...         ...        ...
# 44182  False         False  False      False       False      False
# 44183  False         False  False      False       False      False
# 44184  False         False  False      False       False      False
# 44185  False         False  False      False       False      False
# 44186  False         False  False      False       False      False
#
#        charge240  city08  city08U  cityA08  ...  mfrCode  c240Dscr  \
# 0          False   False    False    False  ...     True      True
# ...

# %%
# get the number of missing data points per column
missing_values_count = df.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count[0:83]
# Out:
# Year                0
# Manufacturer        0
# Model               0
# barrels08           0
# barrelsA08          0
#                 ...
# modifiedOn          0
# startStop       31689
# phevCity            0
# phevHwy             0
# phevComb            0
# Length: 83, dtype: int64

# %%
# how many total missing values do we have?
total_cells = np.product(df.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 13.261791820687598

# %%
# look at the # of missing points in the first ten columns
missing_values_count[0:10]
# Out:
# Year            0
# Manufacturer    0
# Model           0
# barrels08       0
# barrelsA08      0
# charge120       0
# charge240       0
# city08          0
# city08U         0
# cityA08         0
# dtype: int64

# %%
# look at the # of missing points in the first ten columns
missing_values_count[10:20]
# Out:
# cityA08U           0
# cityCD             0
# cityE              0
# cityUF             0
# co2                0
# co2A               0
# co2TailpipeAGpm    0
# co2TailpipeGpm     0
# comb08             0
# comb08U            0
# dtype: int64

# %%
# look at the # of missing points in the first ten columns
missing_values_count[20:30]
# Out:
# combA08           0
# combA08U          0
# combE             0
# combinedCD        0
# combinedUF        0
# cylinders       305
# displ           303
# drive          1186
# engId             0
# eng_dscr      16638
# dtype: int64

# %%
# look at the # of missing points in the first ten columns
missing_values_count[30:40]
# Out:
# feScore        0
# fuelCost08     0
# fuelCostA08    0
# fuelType       0
# fuelType1      0
# ghgScore       0
# ghgScoreA      0
# highway08      0
# highway08U     0
# highwayA08     0
# dtype: int64

# %%
# look at the # of missing points in the first ten columns
missing_values_count[40:50]
# Out:
# highwayA08U    0
# VClass         0
# highwayCD      0
# highwayE       0
# highwayUF      0
# hlv            0
# hpv            0
# id             0
# lv2            0
# lv4            0
# dtype: int64

# %%
# look at the # of missing points in the first ten columns
missing_values_count[50:60]
# Out:
# mpgData        52
# phevBlended     0
# pv2             0
# pv4             0
# range           0
# rangeCity       0
# rangeCityA      0
# rangeHwy        0
# rangeHwyA       0
# trany          11
# dtype: int64

# %%
# look at the # of missing points in the first ten columns
missing_values_count[60:70]
# Out:
# UCity               0
# UCityA              0
# UHighway            0
# UHighwayA           0
# youSaveSpend        0
# guzzler         41582
# trans_dscr      29143
# tCharger        35600
# sCharger        43235
# atvType         40021
# dtype: int64

# %%
# look at the # of missing points in the first ten columns
missing_values_count[70:80]
# Out:
# fuelType2     42421
# rangeA        42426
# evMotor       42815
# mfrCode       30808
# c240Dscr      44069
# charge240b        0
# c240bDscr     44075
# createdOn         0
# modifiedOn        0
# startStop     31689
# dtype: int64

# %%
# look at the # of missing points in the first ten columns
missing_values_count[80:84]
# Out:
# phevCity    0
# phevHwy     0
# phevComb    0
# dtype: int64

# %%
df.fillna(0)
# Out:
#        Year   Manufacturer              Model  barrels08  barrelsA08  \
# 0      1995      Chevrolet    Pickup 2500 4WD  23.543571           0
# 1      1995      Chevrolet    Pickup 2500 4WD  23.886563           0
# 2      1995      Chevrolet     S10 Pickup 4WD  19.388824           0
# 3      1995         Nissan          Truck 4WD  21.974000           0
# 4      1995          Dodge  Dakota Pickup 4WD  25.354615           0
# ...     ...            ...                ...        ...         ...
# 44182  1992        Mercury             Tracer  12.677308           0
# 44183  1992  Mercedes-Benz     300D 2.5 Turbo  15.287400           0
# 44184  1992     Mitsubishi           Diamante  18.311667           0
# 44185  1992     Mitsubishi             Galant  15.695714           0
# 44186  1985           Ford    F250 Pickup 4WD  25.354615           0
#
#        charge120  charge240  city08  city08U  cityA08  ...  mfrCode  c240Dscr  \
# ...

# %%
print(df["Year"].value_counts())
print("No of unique years:",len(df["Year"].unique()))
# Out:
# 1984    1964
# 1985    1701
# 2018    1348
# 2019    1343
# 2017    1293
# 2015    1280
# 2016    1262
# 2021    1259
# 2020    1254
# 1987    1247
# 2014    1221
# 1986    1210
# 2008    1187
# 2009    1181
# 2013    1180
# 2005    1166
# 1989    1153
# 2012    1147
# 1991    1132
# 1988    1130
# 2007    1126
# 2011    1126
# 2004    1122
# 1992    1121
# 2010    1106
# 2006    1104
# 1993    1093
# 1990    1078
# 2003    1044
# 1994     982
# 2002     975
# 1995     967
# 2001     911
# 1999     852
# 2000     840
# 1998     812
# 1996     773
# 1997     762
# 2022     735
# Name: Year, dtype: int64
# No of unique years: 39

# %%
print(df["Manufacturer"].value_counts())
print("No of unique mannufacturers:",len(df["Manufacturer"].unique()))
# Out:
# Chevrolet                             4219
# Ford                                  3540
# GMC                                   2635
# Dodge                                 2632
# Toyota                                2235
#                                       ...
# STI                                      1
# S and S Coach Company  E.p. Dutton       1
# Panoz Auto-Development                   1
# Kandi                                    1
# Vixen Motor Company                      1
# Name: Manufacturer, Length: 141, dtype: int64
# No of unique mannufacturers: 141

# %%
print("No of unique manufacturers for :",len(df["Manufacturer"].unique()))
plt.figure(figsize=(40,10))
df["Manufacturer"].value_counts().plot(kind="bar")
# Out:
# No of unique manufacturers for : 141
# <AxesSubplot:>

# %%
print(df["Model"].value_counts())
print("No of unique models:",len(df["Model"].unique()))
# Out:
# F150 Pickup 2WD                 227
# F150 Pickup 4WD                 207
# Camaro                          206
# Mustang                         203
# Jetta                           196
#                                ...
# Huracan Spyder RWD                1
# E500 4matic (wagon)               1
# ITS 230CE                         1
# Transit Connect Electric Van      1
# Silver Spur II Mpw Touring L      1
# Name: Model, Length: 4521, dtype: int64
# No of unique models: 4521

# %%
print("No of unique models for :",len(df["Model"].unique()))
plt.figure(figsize=(100,10))
df["Model"].value_counts().plot(kind="bar")
# Out:
# No of unique models for : 4521
# <AxesSubplot:>

# %%
def list_and_visualize_missing_data(dataset):
    # Listing total null items and its percent with respect to all nulls
    total = dataset.isnull().sum().sort_values(ascending=False)
    percent = ((dataset.isnull().sum())/(dataset.isnull().count())).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    missing_data = missing_data[missing_data.Total > 0]
    
    missing_data.plot.bar(subplots=True, figsize=(16,9))

list_and_visualize_missing_data(df)

# %%
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
cols = df.columns[:30] # first 30 columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
# if it's a larger dataset and the visualization takes too long can do this.
# % of missing.
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Year - 0%
# Manufacturer - 0%
# Model - 0%
# barrels08 - 0%
# barrelsA08 - 0%
# charge120 - 0%
# charge240 - 0%
# city08 - 0%
# city08U - 0%
# cityA08 - 0%
# cityA08U - 0%
# cityCD - 0%
# cityE - 0%
# cityUF - 0%
# co2 - 0%
# co2A - 0%
# co2TailpipeAGpm - 0%
# co2TailpipeGpm - 0%
# comb08 - 0%
# comb08U - 0%
# combA08 - 0%
# combA08U - 0%
# combE - 0%
# combinedCD - 0%
# combinedUF - 0%
# cylinders - 1%
# displ - 1%
# drive - 3%
# engId - 0%
# eng_dscr - 38%
# feScore - 0%
# fuelCost08 - 0%
# fuelCostA08 - 0%
# fuelType - 0%
# fuelType1 - 0%
# ghgScore - 0%
# ghgScoreA - 0%
# highway08 - 0%
# highway08U - 0%
# highwayA08 - 0%
# highwayA08U - 0%
# VClass - 0%
# highwayCD - 0%
# highwayE - 0%
# highwayUF - 0%
# hlv - 0%
# hpv - 0%
# id - 0%
# lv2 - 0%
# lv4 - 0%
# mpgData - 0%
# phevBlended - 0%
# pv2 - 0%
# pv4 - 0%
# range - 0%
# rangeCity - 0%
# rangeCityA - 0%
# rangeHwy - 0%
# rangeHwyA - 0%
# trany - 0%
# UCity - 0%
# UCityA - 0%
# UHighway - 0%
# UHighwayA - 0%
# ...

# %%
# box plot.
df.boxplot(column=['barrels08'])
# Out:
# <AxesSubplot:>

# %%
# writing to Excel
datatoexcel = pd.ExcelWriter('C:/Users/Pooja/OneDrive/Desktop/fuelData1.xlsx')
  
# write DataFrame to excel
df.to_excel(datatoexcel)
  
# save the excel
datatoexcel.save()
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# determining the name of the file
file_name = 'datacleanfuel.xlsx'
  
# saving the excel
df.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
df.isnull()
# Out:
#         Year  Manufacturer  Model  barrels08  barrelsA08  charge120  \
# 0      False         False  False      False       False      False
# 1      False         False  False      False       False      False
# 2      False         False  False      False       False      False
# 3      False         False  False      False       False      False
# 4      False         False  False      False       False      False
# ...      ...           ...    ...        ...         ...        ...
# 44182  False         False  False      False       False      False
# 44183  False         False  False      False       False      False
# 44184  False         False  False      False       False      False
# 44185  False         False  False      False       False      False
# 44186  False         False  False      False       False      False
#
#        charge240  city08  city08U  cityA08  ...  mfrCode  c240Dscr  \
# 0          False   False    False    False  ...     True      True
# ...

# %%
dg=df.fillna(0)

# %%
dg
# Out:
#        Year   Manufacturer              Model  barrels08  barrelsA08  \
# 0      1995      Chevrolet    Pickup 2500 4WD  23.543571           0
# 1      1995      Chevrolet    Pickup 2500 4WD  23.886563           0
# 2      1995      Chevrolet     S10 Pickup 4WD  19.388824           0
# 3      1995         Nissan          Truck 4WD  21.974000           0
# 4      1995          Dodge  Dakota Pickup 4WD  25.354615           0
# ...     ...            ...                ...        ...         ...
# 44182  1992        Mercury             Tracer  12.677308           0
# 44183  1992  Mercedes-Benz     300D 2.5 Turbo  15.287400           0
# 44184  1992     Mitsubishi           Diamante  18.311667           0
# 44185  1992     Mitsubishi             Galant  15.695714           0
# 44186  1985           Ford    F250 Pickup 4WD  25.354615           0
#
#        charge120  charge240  city08  city08U  cityA08  ...  mfrCode  c240Dscr  \
# ...

# %%
# writing to Excel
datatoexcel = pd.ExcelWriter('C:/Users/Pooja/OneDrive/Desktop/fuelData2.xlsx')
  
# write DataFrame to excel
dg.to_excel(datatoexcel)
  
# save the excel
datatoexcel.save()
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
